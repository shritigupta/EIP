# %% [markdown]
# <a href="https://colab.research.google.com/github/shritigupta/EIP/blob/master/assign5/29_dec_Resnet50_PersonAttrubutes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.applications import ResNet50
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import GlobalAveragePooling2D
from keras.layers import Input
from keras.models import Model,Sequential
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2
from keras import backend as K
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
pixel_level= False
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
augment = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        brightness_range=(0.2,2.5),
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.1,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=1.0/255,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=0.1, pixel_level=pixel_level),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.)

# %%
import keras
import numpy as np
import scipy

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.augmentation = augmentation
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]

        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
      


        if self.augmentation is not None:
          image = self.augmentation.flow(image,shuffle=False).next()
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15,random_state=1)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 58        resized/59.jpg              0  ...                        1              0
# 2106    resized/2107.jpg              1  ...                        1              0
# 5206    resized/5207.jpg              0  ...                        1              0
# 1163    resized/1164.jpg              1  ...                        1              0
# 13534  resized/13536.jpg              1  ...                        0              1
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, shuffle=True, augmentation=ImageDataGenerator(rescale=1.0/255,))
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False, 
                                augmentation=ImageDataGenerator(rescale=1.0/255,))

# %%
# get number of output units from data

images, targets = next(iter(train_gen))
print(images.shape)
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# (32, 224, 224, 3)
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
from keras.callbacks import Callback
import keras.backend as K
import numpy as np

class SGDRScheduler(Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %%
backbone = ResNet50(
    weights=None, 
    include_top=True, 
    input_tensor=Input(shape=(224, 224, 3)),
    classes=27,
    )

neck = backbone.output

neck = Dropout(0.2)(neck)
neck = BatchNormalization()(neck)
neck = Dense(512, activation="relu")(neck)



def build_tower(in_layer):
    #neck = Dropout(0.1)(in_layer)
    neck = Dense(256, activation="relu")(in_layer)
    
    #neck = Dropout(0.1)(neck)
    neck = Dense(128, activation="relu")(neck)
    

    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 27)           55323       avg_pool[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 27)           0           fc1000[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27)           108         dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          14336       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          32896       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          32896       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          32896       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          32896       dense_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          32896       dense_10[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          32896       dense_12[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          32896       dense_16[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          32896       dense_14[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_3[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_5[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_7[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_9[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_11[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_13[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_17[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_15[0][0]
# ==================================================================================================
# Total params: 24,974,754
# Trainable params: 24,921,580
# Non-trainable params: 53,174
# __________________________________________________________________________________________________

# %%
learning_rate = 0.001
opt = SGD(lr=0.001, momentum=0.9)
model.compile(
    optimizer=opt,
    loss='categorical_crossentropy', 
    #loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# freeze backbone
for layer in backbone.layers[0:(len(backbone.layers))]:
	layer.trainable = False

# %%
import numpy as np
from keras.callbacks import LearningRateScheduler

def step_decay_schedule(initial_lr=1e-3, decay_factor=0.75, step_size=10):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        return initial_lr * (decay_factor ** np.floor(epoch/step_size))
    
    return LearningRateScheduler(schedule)

lr_sched = step_decay_schedule(initial_lr=1e-1, decay_factor=0.75, step_size=2)

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
from collections import Counter
import os


# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.

checkpoint = ModelCheckpoint(filepath=filepath,
                             verbose=1,
                             save_best_only=True)


callbacks = [checkpoint,lr_sched]

# %%
import keras.backend as K
from keras.models import load_model

#model = load_model('/content/saved_models/model.006.h5')
# update the learning rate

print("[INFO] old learning rate: {}".format(
		K.get_value(model.optimizer.lr)))
#K.set_value(model.optimizer.lr, 0.000199)

print("[INFO] new learning rate: {}".format(
		K.get_value(model.optimizer.lr)))

#print(len(train_gen))


model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=8, 
    epochs=50,
    verbose=1,
    #class_weight=cw,
    #steps_per_epoch=180, # 128
    callbacks=callbacks,
)
# Out:
# [INFO] old learning rate: 0.0010000000474974513
# [INFO] new learning rate: 0.0010000000474974513
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 360/360 [==============================] - 106s 293ms/step - loss: 7.9026 - gender_output_loss: 0.6827 - image_quality_output_loss: 0.9851 - age_output_loss: 1.4311 - weight_output_loss: 0.9978 - bag_output_loss: 0.9190 - footwear_output_loss: 1.0427 - pose_output_loss: 0.9322 - emotion_output_loss: 0.9119 - gender_output_acc: 0.5613 - image_quality_output_acc: 0.5509 - age_output_acc: 0.4026 - weight_output_acc: 0.6322 - bag_output_acc: 0.5655 - footwear_output_acc: 0.4429 - pose_output_acc: 0.6172 - emotion_output_acc: 0.7140 - val_loss: 8.0241 - val_gender_output_loss: 0.6888 - val_image_quality_output_loss: 1.0002 - val_age_output_loss: 1.4629 - val_weight_output_loss: 0.9840 - val_bag_output_loss: 0.9374 - val_footwear_output_loss: 1.0460 - val_pose_output_loss: 0.9371 - val_emotion_output_loss: 0.9677 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00001: val_loss improved from inf to 8.02413, saving model to /content/saved_models/model.001.h5
# Epoch 2/50
# 360/360 [==============================] - 89s 248ms/step - loss: 7.8567 - gender_output_loss: 0.6815 - image_quality_output_loss: 0.9820 - age_output_loss: 1.4255 - weight_output_loss: 0.9860 - bag_output_loss: 0.9148 - footwear_output_loss: 1.0393 - pose_output_loss: 0.9274 - emotion_output_loss: 0.9003 - gender_output_acc: 0.5616 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4042 - weight_output_acc: 0.6344 - bag_output_acc: 0.5664 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7160 - val_loss: 8.0211 - val_gender_output_loss: 0.7003 - val_image_quality_output_loss: 0.9873 - val_age_output_loss: 1.4564 - val_weight_output_loss: 0.9978 - val_bag_output_loss: 0.9387 - val_footwear_output_loss: 1.0507 - val_pose_output_loss: 0.9279 - val_emotion_output_loss: 0.9622 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00002: val_loss improved from 8.02413 to 8.02114, saving model to /content/saved_models/model.002.h5
# Epoch 3/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.8492 - gender_output_loss: 0.6806 - image_quality_output_loss: 0.9816 - age_output_loss: 1.4231 - weight_output_loss: 0.9859 - bag_output_loss: 0.9143 - footwear_output_loss: 1.0385 - pose_output_loss: 0.9258 - emotion_output_loss: 0.8994 - gender_output_acc: 0.5622 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4042 - weight_output_acc: 0.6343 - bag_output_acc: 0.5669 - footwear_output_acc: 0.4451 - pose_output_acc: 0.6188 - emotion_output_acc: 0.7161
# Epoch 00002: val_loss improved from 8.02413 to 8.02114, saving model to /content/saved_models/model.002.h5
# 360/360 [==============================] - 90s 249ms/step - loss: 7.8488 - gender_output_loss: 0.6806 - image_quality_output_loss: 0.9814 - age_output_loss: 1.4232 - weight_output_loss: 0.9853 - bag_output_loss: 0.9144 - footwear_output_loss: 1.0386 - pose_output_loss: 0.9262 - emotion_output_loss: 0.8991 - gender_output_acc: 0.5622 - image_quality_output_acc: 0.5531 - age_output_acc: 0.4042 - weight_output_acc: 0.6347 - bag_output_acc: 0.5666 - footwear_output_acc: 0.4448 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7161 - val_loss: 8.0159 - val_gender_output_loss: 0.7084 - val_image_quality_output_loss: 0.9866 - val_age_output_loss: 1.4480 - val_weight_output_loss: 0.9843 - val_bag_output_loss: 0.9372 - val_footwear_output_loss: 1.0534 - val_pose_output_loss: 0.9331 - val_emotion_output_loss: 0.9649 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00003: val_loss improved from 8.02114 to 8.01587, saving model to /content/saved_models/model.003.h5
# Epoch 4/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.8440 - gender_output_loss: 0.6799 - image_quality_output_loss: 0.9795 - age_output_loss: 1.4235 - weight_output_loss: 0.9836 - bag_output_loss: 0.9144 - footwear_output_loss: 1.0379 - pose_output_loss: 0.9275 - emotion_output_loss: 0.8978 - gender_output_acc: 0.5592 - image_quality_output_acc: 0.5532 - age_output_acc: 0.4042 - weight_output_acc: 0.6351 - bag_output_acc: 0.5669 - footwear_output_acc: 0.4451 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7164
# 360/360 [==============================] - 90s 250ms/step - loss: 7.8454 - gender_output_loss: 0.6799 - image_quality_output_loss: 0.9797 - age_output_loss: 1.4238 - weight_output_loss: 0.9842 - bag_output_loss: 0.9141 - footwear_output_loss: 1.0380 - pose_output_loss: 0.9274 - emotion_output_loss: 0.8984 - gender_output_acc: 0.5592 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4040 - weight_output_acc: 0.6346 - bag_output_acc: 0.5669 - footwear_output_acc: 0.4451 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7161 - val_loss: 7.9871 - val_gender_output_loss: 0.6952 - val_image_quality_output_loss: 0.9854 - val_age_output_loss: 1.4464 - val_weight_output_loss: 0.9837 - val_bag_output_loss: 0.9394 - val_footwear_output_loss: 1.0468 - val_pose_output_loss: 0.9277 - val_emotion_output_loss: 0.9624 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00004: val_loss improved from 8.01587 to 7.98713, saving model to /content/saved_models/model.004.h5
# Epoch 5/50
# 360/360 [==============================] - 90s 249ms/step - loss: 7.8432 - gender_output_loss: 0.6799 - image_quality_output_loss: 0.9807 - age_output_loss: 1.4223 - weight_output_loss: 0.9834 - bag_output_loss: 0.9137 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9268 - emotion_output_loss: 0.8980 - gender_output_acc: 0.5633 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4038 - weight_output_acc: 0.6348 - bag_output_acc: 0.5668 - footwear_output_acc: 0.4445 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7161 - val_loss: 8.0127 - val_gender_output_loss: 0.7016 - val_image_quality_output_loss: 0.9861 - val_age_output_loss: 1.4528 - val_weight_output_loss: 0.9863 - val_bag_output_loss: 0.9389 - val_footwear_output_loss: 1.0556 - val_pose_output_loss: 0.9278 - val_emotion_output_loss: 0.9635 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00005: val_loss did not improve from 7.98713
# Epoch 6/50
# 360/360 [==============================] - 91s 253ms/step - loss: 7.8402 - gender_output_loss: 0.6793 - image_quality_output_loss: 0.9805 - age_output_loss: 1.4218 - weight_output_loss: 0.9834 - bag_output_loss: 0.9130 - footwear_output_loss: 1.0374 - pose_output_loss: 0.9273 - emotion_output_loss: 0.8976 - gender_output_acc: 0.5626 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4044 - weight_output_acc: 0.6348 - bag_output_acc: 0.5664 - footwear_output_acc: 0.4448 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7160 - val_loss: 8.0086 - val_gender_output_loss: 0.6976 - val_image_quality_output_loss: 0.9848 - val_age_output_loss: 1.4543 - val_weight_output_loss: 0.9870 - val_bag_output_loss: 0.9442 - val_footwear_output_loss: 1.0523 - val_pose_output_loss: 0.9273 - val_emotion_output_loss: 0.9612 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00006: val_loss did not improve from 7.98713
# Epoch 7/50
# 360/360 [==============================] - 90s 250ms/step - loss: 7.8345 - gender_output_loss: 0.6767 - image_quality_output_loss: 0.9804 - age_output_loss: 1.4205 - weight_output_loss: 0.9829 - bag_output_loss: 0.9130 - footwear_output_loss: 1.0375 - pose_output_loss: 0.9268 - emotion_output_loss: 0.8968 - gender_output_acc: 0.5587 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4041 - weight_output_acc: 0.6344 - bag_output_acc: 0.5666 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7161 - val_loss: 8.0406 - val_gender_output_loss: 0.7296 - val_image_quality_output_loss: 0.9850 - val_age_output_loss: 1.4537 - val_weight_output_loss: 0.9835 - val_bag_output_loss: 0.9442 - val_footwear_output_loss: 1.0553 - val_pose_output_loss: 0.9276 - val_emotion_output_loss: 0.9617 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00007: val_loss did not improve from 7.98713
# Epoch 8/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.8319 - gender_output_loss: 0.6773 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4203 - weight_output_loss: 0.9819 - bag_output_loss: 0.9122 - footwear_output_loss: 1.0367 - pose_output_loss: 0.9266 - emotion_output_loss: 0.8964 - gender_output_acc: 0.5564 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4045 - weight_output_acc: 0.6343 - bag_output_acc: 0.5666 - footwear_output_acc: 0.4439 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7161
# Epoch 00007: val_loss did not improve from 7.98713
# Epoch 8/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.8320 - gender_output_loss: 0.6773 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4203 - weight_output_loss: 0.9819 - bag_output_loss: 0.9123 - footwear_output_loss: 1.0366 - pose_output_loss: 0.9266 - emotion_output_loss: 0.8964 - gender_output_acc: 0.5565 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4043 - weight_output_acc: 0.6345 - bag_output_acc: 0.5665 - footwear_output_acc: 0.4437 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7161 - val_loss: 8.0316 - val_gender_output_loss: 0.6990 - val_image_quality_output_loss: 0.9860 - val_age_output_loss: 1.4631 - val_weight_output_loss: 0.9857 - val_bag_output_loss: 0.9424 - val_footwear_output_loss: 1.0564 - val_pose_output_loss: 0.9304 - val_emotion_output_loss: 0.9685 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00008: val_loss did not improve from 7.98713
# Epoch 9/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.8390 - gender_output_loss: 0.6806 - image_quality_output_loss: 0.9818 - age_output_loss: 1.4228 - weight_output_loss: 0.9828 - bag_output_loss: 0.9118 - footwear_output_loss: 1.0370 - pose_output_loss: 0.9265 - emotion_output_loss: 0.8957 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4042 - weight_output_acc: 0.6345 - bag_output_acc: 0.5668 - footwear_output_acc: 0.4458 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7164 - val_loss: 8.0276 - val_gender_output_loss: 0.7021 - val_image_quality_output_loss: 0.9875 - val_age_output_loss: 1.4558 - val_weight_output_loss: 0.9856 - val_bag_output_loss: 0.9431 - val_footwear_output_loss: 1.0623 - val_pose_output_loss: 0.9272 - val_emotion_output_loss: 0.9640 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.4435 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00009: val_loss did not improve from 7.98713
# Epoch 10/50
# 360/360 [==============================] - 90s 251ms/step - loss: 7.8320 - gender_output_loss: 0.6798 - image_quality_output_loss: 0.9813 - age_output_loss: 1.4211 - weight_output_loss: 0.9818 - bag_output_loss: 0.9128 - footwear_output_loss: 1.0328 - pose_output_loss: 0.9259 - emotion_output_loss: 0.8965 - gender_output_acc: 0.5600 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4041 - weight_output_acc: 0.6344 - bag_output_acc: 0.5663 - footwear_output_acc: 0.4553 - pose_output_acc: 0.6183 - emotion_output_acc: 0.7161 - val_loss: 7.9867 - val_gender_output_loss: 0.6867 - val_image_quality_output_loss: 0.9836 - val_age_output_loss: 1.4482 - val_weight_output_loss: 0.9836 - val_bag_output_loss: 0.9390 - val_footwear_output_loss: 1.0560 - val_pose_output_loss: 0.9272 - val_emotion_output_loss: 0.9624 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00010: val_loss improved from 7.98713 to 7.98670, saving model to /content/saved_models/model.010.h5
#
# Epoch 00009: val_loss did not improve from 7.98713Epoch 11/50
# 360/360 [==============================] - 90s 249ms/step - loss: 7.8223 - gender_output_loss: 0.6772 - image_quality_output_loss: 0.9812 - age_output_loss: 1.4196 - weight_output_loss: 0.9798 - bag_output_loss: 0.9114 - footwear_output_loss: 1.0302 - pose_output_loss: 0.9262 - emotion_output_loss: 0.8966 - gender_output_acc: 0.5678 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4043 - weight_output_acc: 0.6345 - bag_output_acc: 0.5666 - footwear_output_acc: 0.4598 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7163 - val_loss: 7.9874 - val_gender_output_loss: 0.6872 - val_image_quality_output_loss: 0.9838 - val_age_output_loss: 1.4498 - val_weight_output_loss: 0.9848 - val_bag_output_loss: 0.9408 - val_footwear_output_loss: 1.0522 - val_pose_output_loss: 0.9278 - val_emotion_output_loss: 0.9610 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00011: val_loss did not improve from 7.98670
# Epoch 00010: val_loss improved from 7.98713 to 7.98670, saving model to /content/saved_models/model.010.h5
#
# Epoch 12/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.8267 - gender_output_loss: 0.6780 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4194 - weight_output_loss: 0.9818 - bag_output_loss: 0.9118 - footwear_output_loss: 1.0348 - pose_output_loss: 0.9259 - emotion_output_loss: 0.8944 - gender_output_acc: 0.5560 - image_quality_output_acc: 0.5539 - age_output_acc: 0.4046 - weight_output_acc: 0.6346 - bag_output_acc: 0.5667 - footwear_output_acc: 0.4466 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7168
# 360/360 [==============================] - 91s 253ms/step - loss: 7.8285 - gender_output_loss: 0.6781 - image_quality_output_loss: 0.9813 - age_output_loss: 1.4199 - weight_output_loss: 0.9817 - bag_output_loss: 0.9117 - footwear_output_loss: 1.0349 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8953 - gender_output_acc: 0.5556 - image_quality_output_acc: 0.5531 - age_output_acc: 0.4044 - weight_output_acc: 0.6347 - bag_output_acc: 0.5667 - footwear_output_acc: 0.4463 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7164 - val_loss: 8.0315 - val_gender_output_loss: 0.7123 - val_image_quality_output_loss: 0.9854 - val_age_output_loss: 1.4549 - val_weight_output_loss: 0.9859 - val_bag_output_loss: 0.9403 - val_footwear_output_loss: 1.0587 - val_pose_output_loss: 0.9293 - val_emotion_output_loss: 0.9648 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00012: val_loss did not improve from 7.98670
# Epoch 13/50
# 360/360 [==============================] - 90s 250ms/step - loss: 7.8103 - gender_output_loss: 0.6724 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4165 - weight_output_loss: 0.9801 - bag_output_loss: 0.9108 - footwear_output_loss: 1.0295 - pose_output_loss: 0.9254 - emotion_output_loss: 0.8950 - gender_output_acc: 0.5609 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4042 - weight_output_acc: 0.6347 - bag_output_acc: 0.5664 - footwear_output_acc: 0.4623 - pose_output_acc: 0.6183 - emotion_output_acc: 0.7164 - val_loss: 8.0477 - val_gender_output_loss: 0.7132 - val_image_quality_output_loss: 0.9871 - val_age_output_loss: 1.4545 - val_weight_output_loss: 0.9872 - val_bag_output_loss: 0.9435 - val_footwear_output_loss: 1.0686 - val_pose_output_loss: 0.9301 - val_emotion_output_loss: 0.9634 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00013: val_loss did not improve from 7.98670
# Epoch 14/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.8156 - gender_output_loss: 0.6729 - image_quality_output_loss: 0.9810 - age_output_loss: 1.4180 - weight_output_loss: 0.9810 - bag_output_loss: 0.9108 - footwear_output_loss: 1.0306 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8957 - gender_output_acc: 0.5551 - image_quality_output_acc: 0.5531 - age_output_acc: 0.4042 - weight_output_acc: 0.6345 - bag_output_acc: 0.5666 - footwear_output_acc: 0.4638 - pose_output_acc: 0.6183 - emotion_output_acc: 0.7159 - val_loss: 8.0448 - val_gender_output_loss: 0.7092 - val_image_quality_output_loss: 0.9868 - val_age_output_loss: 1.4623 - val_weight_output_loss: 0.9884 - val_bag_output_loss: 0.9447 - val_footwear_output_loss: 1.0627 - val_pose_output_loss: 0.9281 - val_emotion_output_loss: 0.9626 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00014: val_loss did not improve from 7.98670
# Epoch 15/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.8049 - gender_output_loss: 0.6699 - image_quality_output_loss: 0.9812 - age_output_loss: 1.4163 - weight_output_loss: 0.9799 - bag_output_loss: 0.9082 - footwear_output_loss: 1.0294 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8943 - gender_output_acc: 0.5624 - image_quality_output_acc: 0.5524 - age_output_acc: 0.4039 - weight_output_acc: 0.6344 - bag_output_acc: 0.5668 - footwear_output_acc: 0.4658 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7164Epoch 15/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.8050 - gender_output_loss: 0.6700 - image_quality_output_loss: 0.9809 - age_output_loss: 1.4160 - weight_output_loss: 0.9797 - bag_output_loss: 0.9085 - footwear_output_loss: 1.0293 - pose_output_loss: 0.9258 - emotion_output_loss: 0.8948 - gender_output_acc: 0.5622 - image_quality_output_acc: 0.5527 - age_output_acc: 0.4043 - weight_output_acc: 0.6345 - bag_output_acc: 0.5665 - footwear_output_acc: 0.4662 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7161 - val_loss: 8.0756 - val_gender_output_loss: 0.7245 - val_image_quality_output_loss: 0.9861 - val_age_output_loss: 1.4630 - val_weight_output_loss: 0.9888 - val_bag_output_loss: 0.9489 - val_footwear_output_loss: 1.0711 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9650 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00015: val_loss did not improve from 7.98670
# Epoch 16/50
# 360/360 [==============================] - 91s 251ms/step - loss: 7.7930 - gender_output_loss: 0.6701 - image_quality_output_loss: 0.9808 - age_output_loss: 1.4128 - weight_output_loss: 0.9790 - bag_output_loss: 0.9060 - footwear_output_loss: 1.0237 - pose_output_loss: 0.9253 - emotion_output_loss: 0.8953 - gender_output_acc: 0.5714 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4043 - weight_output_acc: 0.6343 - bag_output_acc: 0.5668 - footwear_output_acc: 0.4740 - pose_output_acc: 0.6183 - emotion_output_acc: 0.7161 - val_loss: 8.0607 - val_gender_output_loss: 0.7131 - val_image_quality_output_loss: 0.9871 - val_age_output_loss: 1.4663 - val_weight_output_loss: 0.9909 - val_bag_output_loss: 0.9500 - val_footwear_output_loss: 1.0629 - val_pose_output_loss: 0.9285 - val_emotion_output_loss: 0.9620 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00016: val_loss did not improve from 7.98670
# Epoch 17/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7944 - gender_output_loss: 0.6667 - image_quality_output_loss: 0.9809 - age_output_loss: 1.4139 - weight_output_loss: 0.9794 - bag_output_loss: 0.9058 - footwear_output_loss: 1.0262 - pose_output_loss: 0.9254 - emotion_output_loss: 0.8961 - gender_output_acc: 0.5801 - image_quality_output_acc: 0.5533 - age_output_acc: 0.4040 - weight_output_acc: 0.6344 - bag_output_acc: 0.5667 - footwear_output_acc: 0.4681 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7160 - val_loss: 8.0682 - val_gender_output_loss: 0.7140 - val_image_quality_output_loss: 0.9856 - val_age_output_loss: 1.4607 - val_weight_output_loss: 0.9912 - val_bag_output_loss: 0.9512 - val_footwear_output_loss: 1.0748 - val_pose_output_loss: 0.9293 - val_emotion_output_loss: 0.9615 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00017: val_loss did not improve from 7.98670
# Epoch 18/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7869 - gender_output_loss: 0.6674 - image_quality_output_loss: 0.9807 - age_output_loss: 1.4126 - weight_output_loss: 0.9785 - bag_output_loss: 0.9060 - footwear_output_loss: 1.0215 - pose_output_loss: 0.9251 - emotion_output_loss: 0.8951 - gender_output_acc: 0.5787 - image_quality_output_acc: 0.5528 - age_output_acc: 0.4042 - weight_output_acc: 0.6346 - bag_output_acc: 0.5669 - footwear_output_acc: 0.4759 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7162
# Epoch 00017: val_loss did not improve from 7.98670
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7882 - gender_output_loss: 0.6677 - image_quality_output_loss: 0.9804 - age_output_loss: 1.4130 - weight_output_loss: 0.9783 - bag_output_loss: 0.9059 - footwear_output_loss: 1.0215 - pose_output_loss: 0.9257 - emotion_output_loss: 0.8957 - gender_output_acc: 0.5785 - image_quality_output_acc: 0.5531 - age_output_acc: 0.4043 - weight_output_acc: 0.6348 - bag_output_acc: 0.5668 - footwear_output_acc: 0.4758 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7159 - val_loss: 8.0526 - val_gender_output_loss: 0.7096 - val_image_quality_output_loss: 0.9862 - val_age_output_loss: 1.4587 - val_weight_output_loss: 0.9894 - val_bag_output_loss: 0.9462 - val_footwear_output_loss: 1.0745 - val_pose_output_loss: 0.9279 - val_emotion_output_loss: 0.9601 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00018: val_loss did not improve from 7.98670
# Epoch 19/50
# 360/360 [==============================] - 91s 251ms/step - loss: 7.7875 - gender_output_loss: 0.6719 - image_quality_output_loss: 0.9815 - age_output_loss: 1.4128 - weight_output_loss: 0.9784 - bag_output_loss: 0.9067 - footwear_output_loss: 1.0156 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8950 - gender_output_acc: 0.5832 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4043 - weight_output_acc: 0.6348 - bag_output_acc: 0.5667 - footwear_output_acc: 0.4783 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7161 - val_loss: 8.0544 - val_gender_output_loss: 0.7061 - val_image_quality_output_loss: 0.9851 - val_age_output_loss: 1.4582 - val_weight_output_loss: 0.9894 - val_bag_output_loss: 0.9484 - val_footwear_output_loss: 1.0761 - val_pose_output_loss: 0.9287 - val_emotion_output_loss: 0.9622 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00019: val_loss did not improve from 7.98670
# Epoch 20/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7801 - gender_output_loss: 0.6728 - image_quality_output_loss: 0.9812 - age_output_loss: 1.4145 - weight_output_loss: 0.9783 - bag_output_loss: 0.9067 - footwear_output_loss: 1.0051 - pose_output_loss: 0.9259 - emotion_output_loss: 0.8957 - gender_output_acc: 0.5710 - image_quality_output_acc: 0.5528 - age_output_acc: 0.4038 - weight_output_acc: 0.6343 - bag_output_acc: 0.5666 - footwear_output_acc: 0.5028 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7161
# Epoch 00019: val_loss did not improve from 7.98670
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7793 - gender_output_loss: 0.6730 - image_quality_output_loss: 0.9811 - age_output_loss: 1.4144 - weight_output_loss: 0.9782 - bag_output_loss: 0.9064 - footwear_output_loss: 1.0048 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8958 - gender_output_acc: 0.5707 - image_quality_output_acc: 0.5528 - age_output_acc: 0.4040 - weight_output_acc: 0.6344 - bag_output_acc: 0.5668 - footwear_output_acc: 0.5029 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7160 - val_loss: 8.0926 - val_gender_output_loss: 0.7036 - val_image_quality_output_loss: 0.9851 - val_age_output_loss: 1.4584 - val_weight_output_loss: 0.9912 - val_bag_output_loss: 0.9555 - val_footwear_output_loss: 1.1090 - val_pose_output_loss: 0.9279 - val_emotion_output_loss: 0.9618 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00020: val_loss did not improve from 7.98670
# Epoch 21/50
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7768 - gender_output_loss: 0.6755 - image_quality_output_loss: 0.9810 - age_output_loss: 1.4155 - weight_output_loss: 0.9773 - bag_output_loss: 0.9072 - footwear_output_loss: 0.9991 - pose_output_loss: 0.9255 - emotion_output_loss: 0.8957 - gender_output_acc: 0.5549 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4043 - weight_output_acc: 0.6351 - bag_output_acc: 0.5664 - footwear_output_acc: 0.5132 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7160 - val_loss: 8.1108 - val_gender_output_loss: 0.7067 - val_image_quality_output_loss: 0.9857 - val_age_output_loss: 1.4583 - val_weight_output_loss: 0.9920 - val_bag_output_loss: 0.9553 - val_footwear_output_loss: 1.1223 - val_pose_output_loss: 0.9283 - val_emotion_output_loss: 0.9621 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00021: val_loss did not improve from 7.98670
# Epoch 22/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7782 - gender_output_loss: 0.6742 - image_quality_output_loss: 0.9807 - age_output_loss: 1.4128 - weight_output_loss: 0.9778 - bag_output_loss: 0.9082 - footwear_output_loss: 1.0027 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8962 - gender_output_acc: 0.5648 - image_quality_output_acc: 0.5527 - age_output_acc: 0.4040 - weight_output_acc: 0.6344 - bag_output_acc: 0.5664 - footwear_output_acc: 0.5057 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7154Epoch 22/50
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7763 - gender_output_loss: 0.6740 - image_quality_output_loss: 0.9801 - age_output_loss: 1.4127 - weight_output_loss: 0.9779 - bag_output_loss: 0.9078 - footwear_output_loss: 1.0027 - pose_output_loss: 0.9255 - emotion_output_loss: 0.8955 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.5533 - age_output_acc: 0.4038 - weight_output_acc: 0.6346 - bag_output_acc: 0.5667 - footwear_output_acc: 0.5056 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7158 - val_loss: 8.0837 - val_gender_output_loss: 0.7030 - val_image_quality_output_loss: 0.9857 - val_age_output_loss: 1.4591 - val_weight_output_loss: 0.9915 - val_bag_output_loss: 0.9512 - val_footwear_output_loss: 1.1035 - val_pose_output_loss: 0.9282 - val_emotion_output_loss: 0.9614 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00022: val_loss did not improve from 7.98670
# Epoch 23/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7723 - gender_output_loss: 0.6754 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4150 - weight_output_loss: 0.9774 - bag_output_loss: 0.9074 - footwear_output_loss: 0.9958 - pose_output_loss: 0.9255 - emotion_output_loss: 0.8952 - gender_output_acc: 0.5595 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4038 - weight_output_acc: 0.6345 - bag_output_acc: 0.5666 - footwear_output_acc: 0.5180 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7162 - val_loss: 8.1102 - val_gender_output_loss: 0.7046 - val_image_quality_output_loss: 0.9865 - val_age_output_loss: 1.4595 - val_weight_output_loss: 0.9919 - val_bag_output_loss: 0.9510 - val_footwear_output_loss: 1.1263 - val_pose_output_loss: 0.9289 - val_emotion_output_loss: 0.9615 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00023: val_loss did not improve from 7.98670
# Epoch 24/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7715 - gender_output_loss: 0.6745 - image_quality_output_loss: 0.9804 - age_output_loss: 1.4136 - weight_output_loss: 0.9780 - bag_output_loss: 0.9057 - footwear_output_loss: 0.9985 - pose_output_loss: 0.9253 - emotion_output_loss: 0.8954 - gender_output_acc: 0.5615 - image_quality_output_acc: 0.5534 - age_output_acc: 0.4039 - weight_output_acc: 0.6348 - bag_output_acc: 0.5668 - footwear_output_acc: 0.5110 - pose_output_acc: 0.6183 - emotion_output_acc: 0.7161 - val_loss: 8.0904 - val_gender_output_loss: 0.7012 - val_image_quality_output_loss: 0.9866 - val_age_output_loss: 1.4594 - val_weight_output_loss: 0.9920 - val_bag_output_loss: 0.9499 - val_footwear_output_loss: 1.1119 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9610 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00024: val_loss did not improve from 7.98670
# Epoch 24/50
# Epoch 25/50
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7720 - gender_output_loss: 0.6752 - image_quality_output_loss: 0.9807 - age_output_loss: 1.4134 - weight_output_loss: 0.9774 - bag_output_loss: 0.9079 - footwear_output_loss: 0.9962 - pose_output_loss: 0.9260 - emotion_output_loss: 0.8952 - gender_output_acc: 0.5565 - image_quality_output_acc: 0.5532 - age_output_acc: 0.4043 - weight_output_acc: 0.6348 - bag_output_acc: 0.5668 - footwear_output_acc: 0.5162 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7161 - val_loss: 8.1053 - val_gender_output_loss: 0.7035 - val_image_quality_output_loss: 0.9862 - val_age_output_loss: 1.4600 - val_weight_output_loss: 0.9927 - val_bag_output_loss: 0.9500 - val_footwear_output_loss: 1.1232 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9614 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00025: val_loss did not improve from 7.98670
# Epoch 26/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7612 - gender_output_loss: 0.6747 - image_quality_output_loss: 0.9808 - age_output_loss: 1.4139 - weight_output_loss: 0.9769 - bag_output_loss: 0.9072 - footwear_output_loss: 0.9869 - pose_output_loss: 0.9261 - emotion_output_loss: 0.8948 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.5522 - age_output_acc: 0.4040 - weight_output_acc: 0.6348 - bag_output_acc: 0.5669 - footwear_output_acc: 0.5248 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7164Epoch 26/50
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7616 - gender_output_loss: 0.6748 - image_quality_output_loss: 0.9804 - age_output_loss: 1.4137 - weight_output_loss: 0.9771 - bag_output_loss: 0.9075 - footwear_output_loss: 0.9866 - pose_output_loss: 0.9260 - emotion_output_loss: 0.8953 - gender_output_acc: 0.5647 - image_quality_output_acc: 0.5526 - age_output_acc: 0.4043 - weight_output_acc: 0.6347 - bag_output_acc: 0.5666 - footwear_output_acc: 0.5249 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7161 - val_loss: 8.1327 - val_gender_output_loss: 0.7062 - val_image_quality_output_loss: 0.9866 - val_age_output_loss: 1.4604 - val_weight_output_loss: 0.9924 - val_bag_output_loss: 0.9529 - val_footwear_output_loss: 1.1440 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9617 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00026: val_loss did not improve from 7.98670
# Epoch 27/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7666 - gender_output_loss: 0.6765 - image_quality_output_loss: 0.9805 - age_output_loss: 1.4145 - weight_output_loss: 0.9786 - bag_output_loss: 0.9087 - footwear_output_loss: 0.9864 - pose_output_loss: 0.9263 - emotion_output_loss: 0.8951 - gender_output_acc: 0.5627 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4045 - weight_output_acc: 0.6345 - bag_output_acc: 0.5662 - footwear_output_acc: 0.5268 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7162
# Epoch 00026: val_loss did not improve from 7.98670
# Epoch 27/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7647 - gender_output_loss: 0.6764 - image_quality_output_loss: 0.9803 - age_output_loss: 1.4144 - weight_output_loss: 0.9781 - bag_output_loss: 0.9084 - footwear_output_loss: 0.9860 - pose_output_loss: 0.9260 - emotion_output_loss: 0.8950 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4045 - weight_output_acc: 0.6346 - bag_output_acc: 0.5665 - footwear_output_acc: 0.5272 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7162 - val_loss: 8.1271 - val_gender_output_loss: 0.7049 - val_image_quality_output_loss: 0.9866 - val_age_output_loss: 1.4604 - val_weight_output_loss: 0.9927 - val_bag_output_loss: 0.9514 - val_footwear_output_loss: 1.1412 - val_pose_output_loss: 0.9285 - val_emotion_output_loss: 0.9614 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00027: val_loss did not improve from 7.98670
# Epoch 28/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7668 - gender_output_loss: 0.6740 - image_quality_output_loss: 0.9797 - age_output_loss: 1.4133 - weight_output_loss: 0.9783 - bag_output_loss: 0.9073 - footwear_output_loss: 0.9948 - pose_output_loss: 0.9253 - emotion_output_loss: 0.8942 - gender_output_acc: 0.5629 - image_quality_output_acc: 0.5524 - age_output_acc: 0.4040 - weight_output_acc: 0.6346 - bag_output_acc: 0.5669 - footwear_output_acc: 0.5196 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7166
# Epoch 00027: val_loss did not improve from 7.98670
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7669 - gender_output_loss: 0.6740 - image_quality_output_loss: 0.9797 - age_output_loss: 1.4130 - weight_output_loss: 0.9777 - bag_output_loss: 0.9075 - footwear_output_loss: 0.9951 - pose_output_loss: 0.9252 - emotion_output_loss: 0.8947 - gender_output_acc: 0.5626 - image_quality_output_acc: 0.5525 - age_output_acc: 0.4042 - weight_output_acc: 0.6347 - bag_output_acc: 0.5668 - footwear_output_acc: 0.5194 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7162 - val_loss: 8.1477 - val_gender_output_loss: 0.7095 - val_image_quality_output_loss: 0.9877 - val_age_output_loss: 1.4627 - val_weight_output_loss: 0.9936 - val_bag_output_loss: 0.9536 - val_footwear_output_loss: 1.1506 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9616 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00028: val_loss did not improve from 7.98670
# Epoch 29/50
# 360/360 [==============================] - 91s 253ms/step - loss: 7.7649 - gender_output_loss: 0.6757 - image_quality_output_loss: 0.9800 - age_output_loss: 1.4152 - weight_output_loss: 0.9788 - bag_output_loss: 0.9084 - footwear_output_loss: 0.9859 - pose_output_loss: 0.9256 - emotion_output_loss: 0.8954 - gender_output_acc: 0.5624 - image_quality_output_acc: 0.5528 - age_output_acc: 0.4041 - weight_output_acc: 0.6344 - bag_output_acc: 0.5667 - footwear_output_acc: 0.5312 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7160 - val_loss: 8.1341 - val_gender_output_loss: 0.7055 - val_image_quality_output_loss: 0.9874 - val_age_output_loss: 1.4608 - val_weight_output_loss: 0.9931 - val_bag_output_loss: 0.9508 - val_footwear_output_loss: 1.1467 - val_pose_output_loss: 0.9283 - val_emotion_output_loss: 0.9614 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00029: val_loss did not improve from 7.98670
# Epoch 30/50
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7589 - gender_output_loss: 0.6756 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4146 - weight_output_loss: 0.9770 - bag_output_loss: 0.9081 - footwear_output_loss: 0.9811 - pose_output_loss: 0.9258 - emotion_output_loss: 0.8961 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5532 - age_output_acc: 0.4046 - weight_output_acc: 0.6350 - bag_output_acc: 0.5666 - footwear_output_acc: 0.5290 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7158 - val_loss: 8.1311 - val_gender_output_loss: 0.7043 - val_image_quality_output_loss: 0.9868 - val_age_output_loss: 1.4598 - val_weight_output_loss: 0.9926 - val_bag_output_loss: 0.9498 - val_footwear_output_loss: 1.1485 - val_pose_output_loss: 0.9282 - val_emotion_output_loss: 0.9612 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00030: val_loss did not improve from 7.98670
# Epoch 31/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7642 - gender_output_loss: 0.6813 - image_quality_output_loss: 0.9800 - age_output_loss: 1.4179 - weight_output_loss: 0.9786 - bag_output_loss: 0.9085 - footwear_output_loss: 0.9764 - pose_output_loss: 0.9264 - emotion_output_loss: 0.8952 - gender_output_acc: 0.5631 - image_quality_output_acc: 0.5531 - age_output_acc: 0.4043 - weight_output_acc: 0.6341 - bag_output_acc: 0.5668 - footwear_output_acc: 0.5379 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7164Epoch 31/50
#
# Epoch 00030: val_loss did not improve from 7.98670
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7648 - gender_output_loss: 0.6813 - image_quality_output_loss: 0.9802 - age_output_loss: 1.4180 - weight_output_loss: 0.9785 - bag_output_loss: 0.9086 - footwear_output_loss: 0.9764 - pose_output_loss: 0.9263 - emotion_output_loss: 0.8954 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4044 - weight_output_acc: 0.6344 - bag_output_acc: 0.5665 - footwear_output_acc: 0.5378 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7163 - val_loss: 8.1394 - val_gender_output_loss: 0.7005 - val_image_quality_output_loss: 0.9869 - val_age_output_loss: 1.4586 - val_weight_output_loss: 0.9927 - val_bag_output_loss: 0.9502 - val_footwear_output_loss: 1.1613 - val_pose_output_loss: 0.9281 - val_emotion_output_loss: 0.9611 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00031: val_loss did not improve from 7.98670
# Epoch 32/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7577 - gender_output_loss: 0.6795 - image_quality_output_loss: 0.9814 - age_output_loss: 1.4180 - weight_output_loss: 0.9787 - bag_output_loss: 0.9078 - footwear_output_loss: 0.9704 - pose_output_loss: 0.9262 - emotion_output_loss: 0.8957 - gender_output_acc: 0.5625 - image_quality_output_acc: 0.5525 - age_output_acc: 0.4043 - weight_output_acc: 0.6348 - bag_output_acc: 0.5662 - footwear_output_acc: 0.5454 - pose_output_acc: 0.6182 - emotion_output_acc: 0.7159
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7569 - gender_output_loss: 0.6795 - image_quality_output_loss: 0.9810 - age_output_loss: 1.4180 - weight_output_loss: 0.9783 - bag_output_loss: 0.9077 - footwear_output_loss: 0.9706 - pose_output_loss: 0.9263 - emotion_output_loss: 0.8955 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4043 - weight_output_acc: 0.6351 - bag_output_acc: 0.5664 - footwear_output_acc: 0.5451 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7160 - val_loss: 8.1400 - val_gender_output_loss: 0.6992 - val_image_quality_output_loss: 0.9866 - val_age_output_loss: 1.4579 - val_weight_output_loss: 0.9924 - val_bag_output_loss: 0.9507 - val_footwear_output_loss: 1.1639 - val_pose_output_loss: 0.9280 - val_emotion_output_loss: 0.9612 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00032: val_loss did not improve from 7.98670
# Epoch 33/50
# 359/360 [============================>.] - ETA: 0s - loss: 7.7518 - gender_output_loss: 0.6799 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4176 - weight_output_loss: 0.9784 - bag_output_loss: 0.9078 - footwear_output_loss: 0.9671 - pose_output_loss: 0.9260 - emotion_output_loss: 0.8944 - gender_output_acc: 0.5632 - image_quality_output_acc: 0.5528 - age_output_acc: 0.4043 - weight_output_acc: 0.6343 - bag_output_acc: 0.5674 - footwear_output_acc: 0.5472 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7164
# Epoch 00032: val_loss did not improve from 7.98670
# 360/360 [==============================] - 91s 252ms/step - loss: 7.7527 - gender_output_loss: 0.6800 - image_quality_output_loss: 0.9804 - age_output_loss: 1.4177 - weight_output_loss: 0.9788 - bag_output_loss: 0.9078 - footwear_output_loss: 0.9670 - pose_output_loss: 0.9259 - emotion_output_loss: 0.8950 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4041 - weight_output_acc: 0.6343 - bag_output_acc: 0.5670 - footwear_output_acc: 0.5472 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7161 - val_loss: 8.1623 - val_gender_output_loss: 0.6990 - val_image_quality_output_loss: 0.9867 - val_age_output_loss: 1.4579 - val_weight_output_loss: 0.9926 - val_bag_output_loss: 0.9515 - val_footwear_output_loss: 1.1853 - val_pose_output_loss: 0.9281 - val_emotion_output_loss: 0.9612 - val_gender_output_acc: 0.5645 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3656 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.5481 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.6146 - val_emotion_output_acc: 0.6855
#
# Epoch 00033: val_loss did not improve from 7.98670
# Epoch 34/50
#  51/360 [===>..........................] - ETA: 1:16 - loss: 7.7229 - gender_output_loss: 0.6755 - image_quality_output_loss: 0.9775 - age_output_loss: 1.4113 - weight_output_loss: 0.9589 - bag_output_loss: 0.9221 - footwear_output_loss: 0.9769 - pose_output_loss: 0.9176 - emotion_output_loss: 0.8831 - gender_output_acc: 0.5705 - image_quality_output_acc: 0.5564 - age_output_acc: 0.4081 - weight_output_acc: 0.6440 - bag_output_acc: 0.5484 - footwear_output_acc: 0.5374 - pose_output_acc: 0.6287 - emotion_output_acc: 0.7194

# %%
model
